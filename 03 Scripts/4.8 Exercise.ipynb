# %% [markdown]
# # 4.7 Exercise

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Create path
path = r'C:\Users\RebekkaBrandt\Documents\Instacart Basket Analysis'

# %%
# import file
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_2.pkl'))

# %%
# create subset 
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 21)

# %%
df.head(50)
# Out:
#     Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0              0           0   2539329        1             1
# 1              1           1   2398795        1             2
# 2              2           2    473747        1             3
# 3              3           3   2254736        1             4
# 4              4           4    431534        1             5
# 5              5           5   3367565        1             6
# 6              6           6    550135        1             7
# 7              7           7   3108588        1             8
# 8              8           8   2295261        1             9
# 9              9           9   2550362        1            10
# 10           144         144   2968173       15            15
# 11           146         146   1870022       15            17
# 12           147         147   1911383       15            18
# 13           150         150   2715276       15            21
# 14           151         151    487368       15            22
# 15           209         209   2293453       19             2
# 16           212         212   1973799       19             5
# 17           214         214    532817       19             7
# 18           232         232   1573906       21            10
# 19           458         458   1593000       31            10
# 20           465         465   2231262       31            17
# 21           617         617   2580647       43             6
# 22           620         620   2187180       43             9
# 23           751         751   2497897       52             1
# 24           752         752   1318871       52             2
# 25           753         753   1261384       52             3
# 26           755         755    580568       52             5
# 27           757         757   2428073       52             7
# 28           759         759    342306       52             9
# 29           760         760   1520353       52            10
# 30           761         761   2542086       52            11
# 31           762         762    944694       52            12
# 32           765         765   1268191       52            15
# 33           767         767   1122089       52            17
# 34           768         768   1498922       52            18
# 35           769         769    180919       52            19
# 36           771         771   2695875       52            21
# 37          1022        1022   3205960       67             1
# 38          1023        1023    970922       67             2
# 39          1024        1024    596585       67             3
# 40          1025        1025   2037087       67             4
# 41          1026        1026   2474111       67             5
# 42          1027        1027   1568481       67             6
# 43          1029        1029   2048527       67             8
# 44          1030        1030   2389031       67             9
# 45          1031        1031   2378562       67            10
# 46          1032        1032   1515698       67            11
# 47          1033        1033   1928050       67            12
# 48          1034        1034   1949274       67            13
# 49          1035        1035    551869       67            14
#
#     orders_day_of_week  order_hour_of_day  days_since_previous_order  \
# 0                    2                  8                        NaN
# 1                    3                  7                       15.0
# 2                    3                 12                       21.0
# 3                    4                  7                       29.0
# 4                    4                 15                       28.0
# 5                    2                  7                       19.0
# 6                    1                  9                       20.0
# 7                    1                 14                       14.0
# 8                    1                 16                        0.0
# 9                    4                  8                       30.0
# 10                   1                  9                        7.0
# 11                   2                 16                        8.0
# 12                   2                 11                        7.0
# 13                   1                  9                        7.0
# 14                   1                 10                       14.0
# 15                   5                 14                        6.0
# 16                   6                 12                        8.0
# 17                   4                 17                        6.0
# 18                   3                 10                        6.0
# 19                   3                  8                        7.0
# 20                   3                 11                        8.0
# 21                   4                 16                        4.0
# 22                   4                 12                        3.0
# 23                   1                  9                        NaN
# 24                   1                 10                        7.0
# 25                   1                 10                        7.0
# 26                   2                 10                        8.0
# 27                   2                  7                        8.0
# 28                   1                 11                        7.0
# 29                   2                 10                        8.0
# 30                   2                  9                        7.0
# 31                   1                 16                        6.0
# 32                   2                 11                        8.0
# 33                   2                 10                        6.0
# 34                   2                 10                       14.0
# 35                   3                  8                        8.0
# 36                   5                 10                       30.0
# 37                   3                 11                        NaN
# 38                   1                 15                        5.0
# 39                   1                 13                        7.0
# 40                   2                  9                        8.0
# 41                   3                 14                        8.0
# 42                   3                 12                        7.0
# 43                   2                 11                        7.0
# 44                   2                 14                        7.0
# 45                   1                 10                        6.0
# 46                   1                 11                        7.0
# 47                   2                 12                        8.0
# 48                   1                 10                        6.0
# 49                   1                  9                        7.0
#
#     product_id  add_to_cart_order  ...  product_name aisle_id  department_id  \
# 0          196                  1  ...          Soda       77              7
# 1          196                  1  ...          Soda       77              7
# 2          196                  1  ...          Soda       77              7
# 3          196                  1  ...          Soda       77              7
# 4          196                  1  ...          Soda       77              7
# 5          196                  1  ...          Soda       77              7
# 6          196                  1  ...          Soda       77              7
# 7          196                  2  ...          Soda       77              7
# 8          196                  4  ...          Soda       77              7
# 9          196                  1  ...          Soda       77              7
# 10         196                  2  ...          Soda       77              7
# 11         196                  6  ...          Soda       77              7
# 12         196                  1  ...          Soda       77              7
# 13         196                  1  ...          Soda       77              7
# 14         196                  1  ...          Soda       77              7
# 15         196                  3  ...          Soda       77              7
# 16         196                 15  ...          Soda       77              7
# 17         196                  1  ...          Soda       77              7
# 18         196                  2  ...          Soda       77              7
# 19         196                 17  ...          Soda       77              7
# 20         196                 14  ...          Soda       77              7
# 21         196                  9  ...          Soda       77              7
# 22         196                  1  ...          Soda       77              7
# 23         196                  4  ...          Soda       77              7
# 24         196                  5  ...          Soda       77              7
# 25         196                  3  ...          Soda       77              7
# 26         196                  6  ...          Soda       77              7
# 27         196                  5  ...          Soda       77              7
# 28         196                  5  ...          Soda       77              7
# 29         196                  4  ...          Soda       77              7
# 30         196                  3  ...          Soda       77              7
# 31         196                  7  ...          Soda       77              7
# 32         196                  3  ...          Soda       77              7
# 33         196                  4  ...          Soda       77              7
# 34         196                  6  ...          Soda       77              7
# 35         196                  4  ...          Soda       77              7
# 36         196                  1  ...          Soda       77              7
# 37         196                  1  ...          Soda       77              7
# 38         196                  2  ...          Soda       77              7
# 39         196                  2  ...          Soda       77              7
# 40         196                  1  ...          Soda       77              7
# 41         196                  2  ...          Soda       77              7
# 42         196                  2  ...          Soda       77              7
# 43         196                  1  ...          Soda       77              7
# 44         196                  1  ...          Soda       77              7
# 45         196                  1  ...          Soda       77              7
# 46         196                  1  ...          Soda       77              7
# 47         196                  1  ...          Soda       77              7
# 48         196                  1  ...          Soda       77              7
# 49         196                  1  ...          Soda       77              7
#
#     prices  _merge    price_range_loc     busiest_day         busiest_days  \
# 0      9.0    both  Mid-range product  Regularly busy  Regularly busy days
# 1      9.0    both  Mid-range product  Regularly busy      Least busy days
# 2      9.0    both  Mid-range product  Regularly busy      Least busy days
# 3      9.0    both  Mid-range product      Least busy      Least busy days
# 4      9.0    both  Mid-range product      Least busy      Least busy days
# 5      9.0    both  Mid-range product  Regularly busy  Regularly busy days
# 6      9.0    both  Mid-range product  Regularly busy         Busiest days
# 7      9.0    both  Mid-range product  Regularly busy         Busiest days
# 8      9.0    both  Mid-range product  Regularly busy         Busiest days
# 9      9.0    both  Mid-range product      Least busy      Least busy days
# 10     9.0    both  Mid-range product  Regularly busy         Busiest days
# 11     9.0    both  Mid-range product  Regularly busy  Regularly busy days
# 12     9.0    both  Mid-range product  Regularly busy  Regularly busy days
# 13     9.0    both  Mid-range product  Regularly busy         Busiest days
# 14     9.0    both  Mid-range product  Regularly busy         Busiest days
# 15     9.0    both  Mid-range product  Regularly busy  Regularly busy days
# 16     9.0    both  Mid-range product  Regularly busy  Regularly busy days
# 17     9.0    both  Mid-range product      Least busy      Least busy days
# 18     9.0    both  Mid-range product  Regularly busy      Least busy days
# 19     9.0    both  Mid-range product  Regularly busy      Least busy days
# 20     9.0    both  Mid-range product  Regularly busy      Least busy days
# 21     9.0    both  Mid-range product      Least busy      Least busy days
# 22     9.0    both  Mid-range product      Least busy      Least busy days
# 23     9.0    both  Mid-range product  Regularly busy         Busiest days
# 24     9.0    both  Mid-range product  Regularly busy         Busiest days
# 25     9.0    both  Mid-range product  Regularly busy         Busiest days
# 26     9.0    both  Mid-range product  Regularly busy  Regularly busy days
# 27     9.0    both  Mid-range product  Regularly busy  Regularly busy days
# 28     9.0    both  Mid-range product  Regularly busy         Busiest days
# 29     9.0    both  Mid-range product  Regularly busy  Regularly busy days
# 30     9.0    both  Mid-range product  Regularly busy  Regularly busy days
# 31     9.0    both  Mid-range product  Regularly busy         Busiest days
# 32     9.0    both  Mid-range product  Regularly busy  Regularly busy days
# 33     9.0    both  Mid-range product  Regularly busy  Regularly busy days
# 34     9.0    both  Mid-range product  Regularly busy  Regularly busy days
# 35     9.0    both  Mid-range product  Regularly busy      Least busy days
# 36     9.0    both  Mid-range product  Regularly busy  Regularly busy days
# 37     9.0    both  Mid-range product  Regularly busy      Least busy days
# 38     9.0    both  Mid-range product  Regularly busy         Busiest days
# 39     9.0    both  Mid-range product  Regularly busy         Busiest days
# 40     9.0    both  Mid-range product  Regularly busy  Regularly busy days
# 41     9.0    both  Mid-range product  Regularly busy      Least busy days
# 42     9.0    both  Mid-range product  Regularly busy      Least busy days
# 43     9.0    both  Mid-range product  Regularly busy  Regularly busy days
# 44     9.0    both  Mid-range product  Regularly busy  Regularly busy days
# 45     9.0    both  Mid-range product  Regularly busy         Busiest days
# 46     9.0    both  Mid-range product  Regularly busy         Busiest days
# 47     9.0    both  Mid-range product  Regularly busy  Regularly busy days
# 48     9.0    both  Mid-range product  Regularly busy         Busiest days
# 49     9.0    both  Mid-range product  Regularly busy         Busiest days
#
#    busiest_peripd_of_day busiest_period_of_day
# 0         Average Orders        Average Orders
# 1         Average Orders        Average Orders
# 2            Most Orders           Most Orders
# 3         Average Orders        Average Orders
# 4            Most Orders           Most Orders
# 5         Average Orders        Average Orders
# 6            Most Orders           Most Orders
# 7            Most Orders           Most Orders
# 8            Most Orders           Most Orders
# 9         Average Orders        Average Orders
# 10           Most Orders           Most Orders
# 11           Most Orders           Most Orders
# 12           Most Orders           Most Orders
# 13           Most Orders           Most Orders
# 14           Most Orders           Most Orders
# 15           Most Orders           Most Orders
# 16           Most Orders           Most Orders
# 17        Average Orders        Average Orders
# 18           Most Orders           Most Orders
# 19        Average Orders        Average Orders
# 20           Most Orders           Most Orders
# 21           Most Orders           Most Orders
# 22           Most Orders           Most Orders
# 23           Most Orders           Most Orders
# 24           Most Orders           Most Orders
# 25           Most Orders           Most Orders
# 26           Most Orders           Most Orders
# 27        Average Orders        Average Orders
# 28           Most Orders           Most Orders
# 29           Most Orders           Most Orders
# 30           Most Orders           Most Orders
# 31           Most Orders           Most Orders
# 32           Most Orders           Most Orders
# 33           Most Orders           Most Orders
# 34           Most Orders           Most Orders
# 35        Average Orders        Average Orders
# 36           Most Orders           Most Orders
# 37           Most Orders           Most Orders
# 38           Most Orders           Most Orders
# 39           Most Orders           Most Orders
# 40           Most Orders           Most Orders
# 41           Most Orders           Most Orders
# 42           Most Orders           Most Orders
# 43           Most Orders           Most Orders
# 44           Most Orders           Most Orders
# 45           Most Orders           Most Orders
# 46           Most Orders           Most Orders
# 47           Most Orders           Most Orders
# 48           Most Orders           Most Orders
# 49           Most Orders           Most Orders
#
# [50 rows x 21 columns]

# %% [markdown]
# ## Group by

# %%
df.groupby('product_name')

# %%
# mean order number by department
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4                18.825780
# 7                17.472355
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636

# %%
# mean, min, max for order number by department
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 4                18.825780   1  99
# 7                17.472355   1  99
# 13               17.993423   1  99
# 14               19.246334   1  99
# 16               19.463012   1  99
# 17               11.294069   1  98
# 19               19.305237   1  99
# 20               17.599636   1  99

# %%
# group and assign max value for oder number
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0             0           0   2539329        1             1
# 1             1           1   2398795        1             2
# 2             2           2    473747        1             3
# 3             3           3   2254736        1             4
# 4             4           4    431534        1             5
#
#    orders_day_of_week  order_hour_of_day  days_since_previous_order  \
# 0                   2                  8                        NaN
# 1                   3                  7                       15.0
# 2                   3                 12                       21.0
# 3                   4                  7                       29.0
# 4                   4                 15                       28.0
#
#    product_id  add_to_cart_order  ...  aisle_id department_id  prices  _merge  \
# 0         196                  1  ...        77             7     9.0    both
# 1         196                  1  ...        77             7     9.0    both
# 2         196                  1  ...        77             7     9.0    both
# 3         196                  1  ...        77             7     9.0    both
# 4         196                  1  ...        77             7     9.0    both
#
#      price_range_loc     busiest_day         busiest_days  \
# 0  Mid-range product  Regularly busy  Regularly busy days
# 1  Mid-range product  Regularly busy      Least busy days
# 2  Mid-range product  Regularly busy      Least busy days
# 3  Mid-range product      Least busy      Least busy days
# 4  Mid-range product      Least busy      Least busy days
#
#   busiest_peripd_of_day busiest_period_of_day max_order
# 0        Average Orders        Average Orders        10
# 1        Average Orders        Average Orders        10
# 2           Most Orders           Most Orders        10
# 3        Average Orders        Average Orders        10
# 4           Most Orders           Most Orders        10
#
# [5 rows x 22 columns]

# %%
# 'turns off' limitation for number of items shown with .head
pd.options.display.max_rows = None

# %%
# create loc
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %%
ords_prods_merge.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0             0           0   2539329        1             1
# 1             1           1   2398795        1             2
# 2             2           2    473747        1             3
# 3             3           3   2254736        1             4
# 4             4           4    431534        1             5
#
#    orders_day_of_week  order_hour_of_day  days_since_previous_order  \
# 0                   2                  8                        NaN
# 1                   3                  7                       15.0
# 2                   3                 12                       21.0
# 3                   4                  7                       29.0
# 4                   4                 15                       28.0
#
#    product_id  add_to_cart_order  ...  department_id prices  _merge  \
# 0         196                  1  ...              7    9.0    both
# 1         196                  1  ...              7    9.0    both
# 2         196                  1  ...              7    9.0    both
# 3         196                  1  ...              7    9.0    both
# 4         196                  1  ...              7    9.0    both
#
#      price_range_loc     busiest_day         busiest_days  \
# 0  Mid-range product  Regularly busy  Regularly busy days
# 1  Mid-range product  Regularly busy      Least busy days
# 2  Mid-range product  Regularly busy      Least busy days
# 3  Mid-range product      Least busy      Least busy days
# 4  Mid-range product      Least busy      Least busy days
#
#   busiest_peripd_of_day busiest_period_of_day max_order  loyalty_flag
# 0        Average Orders        Average Orders        10  New customer
# 1        Average Orders        Average Orders        10  New customer
# 2           Most Orders           Most Orders        10  New customer
# 3        Average Orders        Average Orders        10  New customer
# 4           Most Orders           Most Orders        10  New customer
#
# [5 rows x 23 columns]

# %%
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             2
# 2         1      New customer             3
# 3         1      New customer             4
# 4         1      New customer             5
# 5         1      New customer             6
# 6         1      New customer             7
# 7         1      New customer             8
# 8         1      New customer             9
# 9         1      New customer            10
# 10       15  Regular customer            15
# 11       15  Regular customer            17
# 12       15  Regular customer            18
# 13       15  Regular customer            21
# 14       15  Regular customer            22
# 15       19      New customer             2
# 16       19      New customer             5
# 17       19      New customer             7
# 18       21  Regular customer            10
# 19       31  Regular customer            10
# 20       31  Regular customer            17
# 21       43  Regular customer             6
# 22       43  Regular customer             9
# 23       52  Regular customer             1
# 24       52  Regular customer             2
# 25       52  Regular customer             3
# 26       52  Regular customer             5
# 27       52  Regular customer             7
# 28       52  Regular customer             9
# 29       52  Regular customer            10
# 30       52  Regular customer            11
# 31       52  Regular customer            12
# 32       52  Regular customer            15
# 33       52  Regular customer            17
# 34       52  Regular customer            18
# 35       52  Regular customer            19
# 36       52  Regular customer            21
# 37       67  Regular customer             1
# 38       67  Regular customer             2
# 39       67  Regular customer             3
# 40       67  Regular customer             4
# 41       67  Regular customer             5
# 42       67  Regular customer             6
# 43       67  Regular customer             8
# 44       67  Regular customer             9
# 45       67  Regular customer            10
# 46       67  Regular customer            11
# 47       67  Regular customer            12
# 48       67  Regular customer            13
# 49       67  Regular customer            14
# 50       67  Regular customer            16
# 51       67  Regular customer            18
# 52       67  Regular customer            19
# 53       67  Regular customer            21
# 54       67  Regular customer            22
# 55       67  Regular customer            23
# 56       81      New customer             3
# 57       81      New customer             5
# 58       82  Regular customer             1
# 59       82  Regular customer             3

# %%
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged_3.pkl'))
