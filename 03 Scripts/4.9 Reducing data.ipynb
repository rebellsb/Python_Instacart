# %% [markdown]
# # Step 1

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\RebekkaBrandt\Documents\Instacart Basket Analysis'

# %%
# Import orders_products_merged.pkl
df_orders_prods_merged = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_4.pkl'))

# %%
df_orders_prods_merged.info()

# %%
df_orders_prods_merged_1 = df_orders_prods_merged.drop(columns = ['Unnamed: 0'])

# %%
df_orders_prods_merged_2 = df_orders_prods_merged_1.drop(columns = ['Unnamed: 0.1'])

# %%
df_orders_prods_merged_2.head()

# %%
df_orders_prods_merged_2.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged_4sm.pkl'))

# %% [markdown]
# # Step 2

# %%
# Import orders_products_merged.pkl
df_orders_prods_merged = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_4sm.pkl'))

# %%
df_orders_prods_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32404859 entries, 0 to 32404858
# Data columns (total 26 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   order_id                   int64
#  1   user_id                    int64
#  2   order_number               int64
#  3   orders_day_of_week         int64
#  4   order_hour_of_day          int64
#  5   days_since_previous_order  float64
#  6   product_id                 int64
#  7   add_to_cart_order          int64
#  8   reordered                  int64
#  9   product_name               object
#  10  aisle_id                   int64
#  11  department_id              int64
#  12  prices                     float64
#  13  _merge                     category
#  14  price_range_loc            object
#  15  busiest_day                object
#  16  busiest_days               object
#  17  busiest_peripd_of_day      object
#  18  busiest_period_of_day      object
# ...

# %%
# Change types for ords data set
df_orders_prods_merged['order_id']=df_orders_prods_merged['order_id'].astype('int32')
df_orders_prods_merged['user_id'] = df_orders_prods_merged['user_id'].astype('int32')
df_orders_prods_merged['order_number']=df_orders_prods_merged['order_number'].astype('int8')
df_orders_prods_merged['orders_day_of_week']=df_orders_prods_merged['orders_day_of_week'].astype('int8')
df_orders_prods_merged['order_hour_of_day']=df_orders_prods_merged['order_hour_of_day'].astype('int8')
df_orders_prods_merged['days_since_previous_order']=df_orders_prods_merged['days_since_previous_order'].astype('float16')

# %%
# Change types for ords data set
df_orders_prods_merged['product_id']=df_orders_prods_merged['product_id' ].astype('int32')
df_orders_prods_merged['add_to_cart_order'] = df_orders_prods_merged['add_to_cart_order'].astype('int32')
df_orders_prods_merged['reordered']=df_orders_prods_merged['reordered'].astype('int8')
df_orders_prods_merged['aisle_id']=df_orders_prods_merged['aisle_id'].astype('int8')
df_orders_prods_merged['department_id']=df_orders_prods_merged['department_id'].astype('int8')
df_orders_prods_merged['prices']=df_orders_prods_merged['prices'].astype('float16')

# %%
df_orders_prods_merged['max_order']=df_orders_prods_merged['max_order'].astype('int8')
df_orders_prods_merged['avg_price']=df_orders_prods_merged['avg_price'].astype('float16')
df_orders_prods_merged['order_freq']=df_orders_prods_merged['order_freq'].astype('float16')

# %%
df_orders_prods_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32404859 entries, 0 to 32404858
# Data columns (total 26 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   order_id                   int32
#  1   user_id                    int32
#  2   order_number               int8
#  3   orders_day_of_week         int8
#  4   order_hour_of_day          int8
#  5   days_since_previous_order  float16
#  6   product_id                 int32
#  7   add_to_cart_order          int32
#  8   reordered                  int8
#  9   product_name               object
#  10  aisle_id                   int8
#  11  department_id              int8
#  12  prices                     float16
#  13  _merge                     category
#  14  price_range_loc            object
#  15  busiest_day                object
#  16  busiest_days               object
#  17  busiest_peripd_of_day      object
#  18  busiest_period_of_day      object
# ...

# %%
df_orders_prods_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_previous_order  product_id  add_to_cart_order  reordered  \
# 0                        NaN         196                  1          0
# 1                       15.0         196                  1          1
# 2                       21.0         196                  1          1
# 3                       29.0         196                  1          1
# 4                       28.0         196                  1          1
#
#   product_name  ...         busiest_days  busiest_peripd_of_day  \
# ...

# %%
df_orders_prods_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged_5sm.pkl'))

# %%
# import customer
df_cust = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'customer.pkl'))

# %%
df_cust.head()
# Out:
#    Unnamed: 0  user_id first_name last_name  gender       state  age  \
# 0           0    26711    Deborah  Esquivel  Female    Missouri   48
# 1           1    33890   Patricia      Hart  Female  New Mexico   36
# 2           2    65803    Kenneth    Farley    Male       Idaho   35
# 3           3   125935   Michelle     Hicks  Female        Iowa   40
# 4           4   130797        Ann   Gilmore  Female    Maryland   26
#
#   date_joined  number_of_dependants family_status  income
# 0    1/1/2017                     3       married  165665
# 1    1/1/2017                     0        single   59285
# 2    1/1/2017                     2       married   99568
# 3    1/1/2017                     0        single   42049
# 4    1/1/2017                     1       married   40374
